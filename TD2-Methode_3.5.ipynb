# %%
import csv
import operator
import random
import time
My_name = 'zitouni'
list_my_data = []
best_gene_C = []
gene_X = []
gene_Y = 0
sum_gene_X = []
sum_gene_Y = 0
distance = 0
is_inte = True
    
def openCSV():
    is_my_range = False
    data = csv.reader(open('ExamColl.csv'),delimiter=',')
    sortedlist = sorted(data, key=operator.itemgetter(0), reverse=True)
    for x in sortedlist :
        res = True
                        
        if x[0] == My_name :
            is_my_range = True
        elif is_my_range  :
            break
        if is_my_range :
            #test si Xi a une valeur vide
            if x.count('') > 0 : #x[1] == '' or x[2] == '' or x[3] == '' or x[4] == '' or x[5] == '' or x[6] == '' :
                res = False
    #         elif x[1] == '0' or x[2] == '0' or x[3] == '0' or x[4] == '0' or x[5] == '0' or x[6] == '0' : or x[5] == '0'  or x[2] == '0'  or x[4] == '0'
             #test si Xi a une valeur 0 ou y = 0 
            elif x.count('0') > 0 :
                 res = False
             #test si Xi ou y sont des entieres 
            elif str(x[1]).find('.')  != -1 or str(x[2]).find('.')  != -1 or str(x[3]).find('.')  != -1 or str(x[4]).find('.')  != -1 or str(x[5]).find('.')  != -1 or str(x[6]).find('.')  != -1 :
                res = False
            #test si Xi €[-1000,1000] 
            elif  int(x[1]) > 1000 or  int(x[1]) < -1000  or   int(x[2]) > 1000 or  int(x[2]) < -1000  or   int(x[3]) > 1000 or  int(x[3]) < -1000  or  int(x[4]) > 1000 or  int(x[4]) < -1000  or   int(x[5]) > 1000 or  int(x[5]) < -1000 :    

                    res = False
            else : 
             #test si Y appartient a la  SOMME de X * C  avec C = 
                y =  abs(int(x[6])) 
                pire_X1 = abs(int(x[1]) * 1000 ) + abs (int(x[2]) * 1000) + abs(int(x[3]) * 1000) + abs(int(x[4]) * 1000) + abs(int(x[5]) * 1000 )
                if y > pire_X1 :
                    res = False
    
            if res :
                gene = [int(x[1]),int(x[2]),int(x[3]),int(x[4]),int(x[5]),int(x[6])]
#                 print(x)
                list_my_data.append(gene)
                
    
    print("openCSV2 : ---- list_my_data length : ",len(list_my_data)," pour : ",My_name)    

def get_gene_Y():
    return sum([i[5] for i in list_my_data])
def get_gene_X():
    res = []
    [res.append(sum([i[k] for i in list_my_data])) for k  in range(5)]
    return res

def normalistion_Y() : 
    global list_my_data
    for x in list_my_data :
        if x[5] < 0:
#             print("AV==========>",x)
            for k in range(6):
                x[k] *= -1
#             print("AP==========>",x)

def init_Gene_X_Y():
    global sum_gene_X,sum_gene_Y
    openCSV()
#     normalistion_Y()
    sum_gene_Y = get_gene_Y()
    print("gene_Y",sum_gene_Y)
    sum_gene_X = get_gene_X()
    print("gene_X",sum_gene_X)

    
    
    
    
    
    
    
    
    
    
    
    
    
    
def get_distance(gene_Co):
    if not(list_my_data):
        init_Gene_X_Y()
    if is_inte : 
        return abs (gene_Y -  sum([(x*c) for x, c in zip(gene_X, gene_Co)]))
    else :
        res = 0 
        for i in range(5):
            res += abs (list_my_data[i][5] -  sum([(x*c) for x, c in zip(list_my_data[i][:5], gene_Co)]))
        return res
#         print(sum_gene_Y,sum_gene_X)
#         return abs (sum_gene_Y -  sum([(x*c) for x, c in zip(sum_gene_X, gene_Co)]))
    
def get_best(list_Gene):
    length_Samll_Gene = 999999999
    liste_2 = []
    liste_3 = []
    for x in list_Gene:
        dist = get_distance(x)
        if dist < length_Samll_Gene:
            length_Samll_Gene = dist
            le_plus_petit = x
            liste_2.insert(0, [dist, x])
        else:
            liste_2.append([dist, x])
    liste_2.sort()
    liste_3 = liste_2
    liste_2 = [i[1] for i in list(liste_2)]
    return le_plus_petit, length_Samll_Gene, liste_2,liste_3
    

def geneC_list_init():
        tille_gene = 5 #len(gene_X)
        liste_gene_C = []
        [liste_gene_C.append([random.randint(-1000, 1000) for _ in range(tille_gene)]) for _ in range(100)]     
        return liste_gene_C
#get_best(geneC_list_init())







def crossover3(best_liste, list_Gene): 
    
    parent1 = []; parent2 = []; parent3 = [];parent4 = []; fils1 = []; fils2 = []; fils3 = []; taille_best = len(best_liste); taille_listG = len(list_Gene)
    
    sequence_gene_best =list_Gene[random.randint(0,taille_best -1)]
    sequence_gene_p =list_Gene[random.randint(0,taille_listG -1)]
    sequence_gene_p2 =list_Gene[random.randint(0,taille_listG -1)]
  
    [ parent1.append(sequence_gene_best[k]) if k <= 2 else parent1.append(sequence_gene_p[k]) for k in range(5)] 
    [ parent2.append(sequence_gene_best[k]) if k > 2 else parent2.append(sequence_gene_p2[k]) for k in range(5)] 
    
    [fils1.append(random.choices( [random.choices(parent1)[0],random.choices(parent2)[0] ])[0]  ) for k in range(5)]
    
    return fils1

       
def crossover_best_C(dis):
    parent3 = [];parent4 = []; fils1 = []; fils2 = []; fils3 = [];
    sequence_gene_C_best =best_gene_C[random.randint(dis,len(best_gene_C) -1)]
    sequence_gene_C_p =best_gene_C[random.randint(0,len(best_gene_C) -1)]
    [ parent3.append(sequence_gene_C_best[k]) if k <= 2 else parent3.append(sequence_gene_C_p[k]) for k in range(5)] 
    [ parent4.append(sequence_gene_C_best[k]) if k >= 2 else parent4.append(sequence_gene_C_p[k]) for k in range(5)] 
    
    [fils2.append(random.choices( [random.choices(parent3)[0],random.choices(parent4)[0] ])[0]  ) for k in range(5)]
    
    if  fils2 in best_gene_C :
        return crossover_best_C(dis)
    return fils2 ,parent3,parent4
    
def new_generation(listmot):

    M_liste = []
    taille_liste = 100
    if distance < 15 :
        taille_liste =  int(taille_liste * 0.5)
        taille_Best_liste = 3
        maxRatio_mutation = 95
        intput_mutation   = 30
    elif  distance < 50 :
        taille_liste = int (taille_liste * 0.8)
        taille_Best_liste = 3
        maxRatio_mutation = 85
        intput_mutation   = 30
    elif distance < 101 :
        taille_liste *= int (taille_liste * 0.7)
        taille_Best_liste = 3
        intput_mutation   = 90
        maxRatio_mutation = 90
    else :
        taille_liste = int (taille_liste * 1.3)
        taille_Best_liste = 3
        intput_mutation   = 95
        maxRatio_mutation = 100
        

    M_liste = listmot[:taille_Best_liste]
    min_intput_mutation= intput_mutation - 15
    max_intput_mutation= intput_mutation + 5
    it = int(random.randint( min_intput_mutation ,max_intput_mutation))
    it /= 100
    len_ma_liste = taille_liste - taille_Best_liste  
    nb_it_mutation = int( len_ma_liste * it)
    nb_cros = int((len_ma_liste - nb_it_mutation)/2)
#     [ M_liste.extend( crossover2(listmot[:4],listmot)) for _ in range(53) ]#M_liste[:taille_Best_liste],
     
    [ M_liste.append( crossover3(listmot[:taille_Best_liste],M_liste)) for _ in range(2) ]
    [ M_liste.append( mutation( random.choices(M_liste[:taille_Best_liste])[0], maxRatio_mutation)) for _ in range(18) ]
#     [ M_liste.append( mutation(M_liste[0], maxRatio_mutation)) for _ in range(nb_it_mutation) ]
    return M_liste           
                  
                  
                                 
    
def mutation(mot, prob):
    if distance < 15:
        mini = -3
        maxi = 3
    elif distance < 50:
        mini = -10
        maxi = 10
    elif distance < 100:
        mini = -10
        maxi = 10
    elif  distance < 1000:
        mini = -10
        maxi = 10
    else:
        mini = -10
        maxi = 10
    if not is_inte : 
        mini = -5
        maxi = 5
    res = []  
    for x in mot:
        if round(random.uniform(0.00, 100.00), 3) <= prob:
            if round(random.uniform(0.00, 100.00), 3) <= 3.75:
                rs = -1 * x
            else :
                miniX = mini + x
                maxiX = maxi + x
                if maxiX > 1000:
                    maxiX = 1000
                if miniX < -1000: 
                    miniX = -1000
                rs = random.randint(miniX, maxiX)  
        else :
            rs = x
        res.append(rs)                 
    return res

                  
                  
                  
def est_resolut(gene_c)  :
    re_b = 0
    for xp in list_my_data :
        rp = (xp[5] -  sum([(xi*c) for xi, c in zip(xp, gene_c)]))
#         print(xp,"==>", rp)
        if rp == 0 :
            re_b +=1
            print(xp)
#         else:
#             return re_b 
      
    return re_b
                  
def Evolution ()  :
    print('*************************************************EVOLUTIONNNNNNNNNNN***************************')
    global distance , best_gene_C,gene_X,gene_Y,is_inte

    res_rond = random.randint( 0 ,46)
    mdr =0
    init_pp =  geneC_list_init()
    for genex in list_my_data :
        gene_X = genex[:5]
        gene_Y =  genex[5]
#         print("xi; ", gene_X)
#         print( "y: ",gene_Y)
        is_end = False
        nk = 0 
        res = 0
        min_id = len(list_my_data)
        if min_id == 0:
            min_id = 1
        population2 =   init_pp 
        best = get_best(population2)
        distance = best[1]
        mindis = distance
        while res < 2:
            best = get_best(population2)
            distance = best[1]
            population2 = new_generation(best[2])
            if mindis > distance :
                mindis=distance
                nk = 0
#                 print("best D:",str(distance), "  --best[0] :",best[0],"---")
            if   mindis == distance:
                nk +=1
                if nk >= 5000: 
                    is_end = True
                    print ("BREAKING IN ==>",distance)
                    break
            if distance == 0 :
                mindis = 9999
                if not best[0] in best_gene_C :
#                    - nb_resolut = est_resolut(best[0])
#                     print("--------------------------",mdr,"-------->",best[0])
                    best_gene_C.append(best[0] )
#                     print("Gene C==>",len(best_gene_C))    
                    res +=1

#                 if len(list_my_data) -   min_id < 2 :
                population2 = init_pp
                    
#                 else:
#                     [ population2.append(crossover_best_C(0)) for _ in range(10) ]
                 
        mdr +=1
        if mdr == 5 :
            break
#         print("--------------------------",mdr,"-------->",len(best_gene_C))
#         print (res)
        
    
    print('*************************************************END_EVOLUTIONNNNNNNNNNN_END***************************') 
    is_inte = False
                  
                  
                  
print("--------------------------exo4---------------------") 
init_Gene_X_Y()
# print(list_my_data)
# [-664, -776, -201, 832, 844 ]
# 53, -526, -787, -717, -712,123922

str_tim = time.time()
Evolution()
res_rond = random.randint( 0 ,len(list_my_data)-1)
gene_X = list_my_data[res_rond][:5]
gene_Y =  list_my_data[res_rond][5]
gene_C = []

# print(est_resolut(gene_C))
# ui= [-908, 646, 384, 45, -63] #---2
# #xi = [-1316, 6339, -4405, -3323, -10563]
# xi = list_my_data[0][:5]
# print("xi; ", gene_X)
# print( "y: ",gene_Y)
# print('-------------------------------------------------------')
# re_b = 0 
# for x in list_my_data :
#     rp = x[5] - sum([gene_C[m]*x[m] for m in range(5)]) 
#     if rp == 0 :
#         re_b +=1
#         print(x)
# print(re_b)
start = time.time()
print('------------------------------------------------------->',start- str_tim,"s")
print("gene_Y",sum_gene_Y)
print("gene_X",sum_gene_X)

print("xi; ", gene_X)
print( "y: ",gene_Y)
mindis = 0
population = geneC_list_init()
best = get_best(population)
distance = best[1]
mindis = distance
print("best D:",str(distance))
nb = 1
nb_resolut = 0
res_blc = 0
it_meme = 0
##############################
tm =  1200
pp =  []
[ pp.extend(crossover_best_C(0)) for _ in range(5) ]
pp.extend(best_gene_C)
population = pp  
best = get_best(population)
distance = best[1]
###############################""
# gene_Y = get_gene_Y()
# print("gene_Y",gene_Y)
# gene_X = get_gene_X()
# print("gene_X",gene_X)
while time.time() - start < tm or nb_resolut >= len(list_my_data)  :
    population = new_generation(best[2])
    best = get_best(population)
    distance = best[1]
    if mindis > distance :
        mindis=distance
        print(distance," =>",best[0])
        it_meme = 0
    elif mindis == distance :
        it_meme += 1
#         print(it_meme)
    
#         print("best D:",str(distance), "  --best[0] :",best[0],"---")
   
    if distance == 0 :
        nb_resolut = est_resolut(best[0])
        gene_C = []
        print("------------------",nb_resolut ,"---------------->",best[0])
     
        nb_res = est_resolut(gene_C)

        if not best[0] in best_gene_C :
            print("dit 0")
            best_gene_C.append(best[0] )
            print("Gene C==>",len(best_gene_C))
      
        if len(best_gene_C)>=6 :  
            est_change = False
            population.clear()
            if round(random.uniform(0.00, 100.00), 3) <= 33.45  :
                if len(best_gene_C) < 350 : 
        
                    res_rond = random.randint( 0 ,len(list_my_data)-1)
                    gene_X = list_my_data[res_rond][:5]
                    gene_Y =  list_my_data[res_rond][5]
                else :
                    print("yesssssssssssssssssssssssssssssssssss")
                    gene_Y = get_gene_Y()
                    gene_X = get_gene_X()
                print("   *********************EV****************")
# #                 res_rond = random.randint( 0 ,46)
# #                 rgene = list_my_data[res_rond][:5]
# #                 for k in range(5) : 
# #                     gene_X[k] += rgene[k] 
# #                 gene_Y +=  list_my_data[res_rond][5]
#                 Evolution()
# #                 print("xi; ", gene_X)
# #                 print( "y: ",gene_Y)
#                 population = geneC_list_init()
# #                 est_change = True
#                 res_blc = 0
            
            if round(random.uniform(0.00, 100.00), 3) <= 0.75  :
                print("change pp--------------------------------------")
                pp = []
                [ pp.extend(crossover_best_C(0)) for _ in range(1) ]
            population = pp
            
        else:
             population = geneC_list_init()
      
        best = get_best(population)
        distance = best[1]
        mindis = distance
        nb += 1
        res_blc +=1
        it_meme = 0
    elif it_meme > 500000 :
        it_meme = 0
        population = []
        population = pp
        print("breaking")
#         [ population.extend(crossover_best_C(0)) for _ in range(1) ]
        best = get_best(population)
        distance = best[1]
        mindis = distance
       
        

print("After 15 minutes, finished", "times and stopped with a distance of", distance, " moyenne : ",best[0], " ******",nb,"*********",tm/nb,"*")

calssement =[]
it = 0
k = []
nb = 0
for lm in range(30) : 
    calssement.append([lm,k])
for ge in best_gene_C : 
    for i in range(5) :
        nb = 0
        for g in best_gene_C : 
            nb +=  g.count(ge[i])
        if nb > 0 and (not ge[i] in calssement[nb][1]):
            calssement[nb].append(ge[i])
        
        
            
sorted(calssement, key=operator.itemgetter(0), reverse=True)
print(calssement)
                  
             #     best D: 0   --best[0] : [306, 306, -897, 307, 305] ---Xi [53, -526, -787, -717, -712,123922] --2best ==> [-696, -341, -251, 641, -342]-- 3eme [-357, -192, -635, -639, -176]
# Out:
# --------------------------exo4---------------------
# openCSV2 : ---- list_my_data length :  47  pour :  zitouni
# gene_Y 10958243
# gene_X [-771, 2592, -5387, -7259, -2087]
# *************************************************EVOLUTIONNNNNNNNNNN***************************
# *************************************************END_EVOLUTIONNNNNNNNNNN_END***************************
# -------------------------------------------------------> 2.5890491008758545 s
# gene_Y 10958243
# gene_X [-771, 2592, -5387, -7259, -2087]
# xi;  [744, -483, 730, -53, -116]
# y:  -1323259
# best D: 1726963
# 852462  => [-855, 986, -775, -649, 594]
# 848464  => [-856, 989, -770, -651, 589]
# 835805  => [-861, 982, -772, -657, 597]
# 827645  => [-854, 975, -765, -658, 600]
# 808583  => [-858, 972, -763, -662, 605]
# 794269  => [-858, 967, -760, -666, 610]
# 789796  => [-854, 981, -757, -668, 607]
# 782025  => [-847, 984, -755, -667, 613]
# 775977  => [-847, 979, -755, -670, 614]
# 766252  => [-850, 978, -750, -672, 616]
# 754158  => [-849, 981, -751, -679, 619]
# 743403  => [-854, 976, -750, -684, 623]
# 739371  => [-846, 986, -747, -683, 623]
# 732687  => [-849, 972, -751, -692, 619]
# 724364  => [-846, 974, -752, -697, 620]
# 712961  => [-856, 986, -739, -697, 621]
# 704637  => [-851, 981, -735, -700, 616]
# 691708  => [-846, 980, -730, -704, 614]
# 685810  => [-847, 978, -729, -709, 610]
# 677859  => [-846, 978, -722, -705, 617]
# 664957  => [-842, 982, -720, -710, 619]
# 654413  => [-837, 976, -729, -723, 617]
# 647254  => [-850, 986, -720, -724, 618]
# 636381  => [-852, 988, -716, -727, 621]
# 623077  => [-848, 988, -714, -731, 625]
# 614570  => [-846, 984, -710, -733, 624]
# 601785  => [-848, 980, -705, -736, 627]
# 599137  => [-838, 987, -706, -737, 626]
# 589649  => [-835, 992, -702, -741, 623]
# 571337  => [-831, 994, -697, -746, 627]
# 562756  => [-832, 997, -692, -749, 625]
# 551431  => [-828, 997, -691, -753, 628]
# 543037  => [-840, 989, -685, -757, 626]
# 534164  => [-836, 985, -684, -763, 621]
# 523522  => [-824, 992, -685, -758, 642]
# 511725  => [-823, 993, -682, -763, 642]
# 503210  => [-818, 996, -684, -768, 644]
# 497045  => [-815, 1000, -675, -764, 645]
# 488126  => [-824, 995, -673, -769, 647]
# 477135  => [-821, 991, -671, -771, 652]
# 469370  => [-822, 993, -666, -771, 655]
# 464272  => [-821, 991, -665, -775, 651]
# 454015  => [-824, 993, -665, -780, 656]
# 443474  => [-819, 991, -660, -780, 659]
# 436333  => [-818, 994, -657, -787, 649]
# 429299  => [-815, 993, -653, -789, 646]
# 425471  => [-814, 998, -653, -793, 643]
# 419662  => [-817, 987, -647, -791, 645]
# 409529  => [-810, 996, -645, -796, 645]
# 403379  => [-805, 992, -646, -798, 645]
# 397016  => [-803, 998, -635, -792, 648]
# 388782  => [-798, 997, -636, -797, 649]
# 382409  => [-798, 988, -634, -800, 645]
# 373643  => [-794, 990, -633, -803, 647]
# 370624  => [-790, 990, -632, -805, 652]
# 368753  => [-792, 988, -628, -809, 651]
# 361033  => [-789, 986, -623, -807, 653]
# 355972  => [-790, 984, -622, -810, 648]
# 347235  => [-788, 981, -617, -812, 648]
# 335116  => [-784, 979, -612, -816, 647]
# 330294  => [-782, 979, -618, -824, 641]
# 318864  => [-777, 976, -612, -822, 644]
# 315112  => [-773, 977, -608, -820, 649]
# 303156  => [-768, 974, -604, -820, 650]
# 296453  => [-763, 973, -605, -821, 648]
# 290828  => [-762, 972, -606, -826, 646]
# 286593  => [-764, 967, -605, -830, 644]
# 284820  => [-762, 967, -606, -835, 645]
# 274353  => [-757, 968, -601, -834, 645]
# 266151  => [-753, 963, -600, -837, 648]
# 260086  => [-752, 964, -599, -839, 642]
# 260008  => [-753, 966, -601, -844, 638]
# 251876  => [-744, 964, -596, -838, 646]
# 243782  => [-739, 959, -596, -843, 643]
# 236580  => [-741, 960, -590, -843, 644]
# 228666  => [-741, 950, -590, -849, 646]
# 220438  => [-736, 958, -586, -853, 642]
# 214128  => [-735, 953, -586, -856, 641]
# 206273  => [-741, 941, -580, -861, 636]
# 201563  => [-733, 934, -582, -860, 649]
# 197964  => [-732, 937, -578, -859, 647]
# 191871  => [-729, 944, -577, -859, 641]
# 186834  => [-721, 939, -575, -854, 653]
# 182434  => [-720, 938, -571, -858, 656]
# 178243  => [-716, 937, -572, -859, 656]
# 175471  => [-715, 937, -571, -861, 656]
# 169832  => [-711, 937, -571, -866, 657]
# 168192  => [-710, 941, -569, -862, 657]
# 158761  => [-707, 944, -564, -866, 653]
# 152680  => [-702, 944, -560, -863, 658]
# 145577  => [-698, 949, -556, -867, 656]
# 141378  => [-693, 947, -560, -865, 659]
# 132861  => [-688, 947, -558, -870, 660]
# 123160  => [-683, 952, -555, -868, 656]
# 122665  => [-683, 952, -553, -872, 657]
# 118894  => [-679, 953, -556, -875, 657]
# 113412  => [-676, 953, -552, -869, 659]
# 110138  => [-672, 950, -553, -874, 658]
# 106581  => [-672, 954, -547, -871, 657]
# 106087  => [-668, 955, -550, -874, 662]
# 101089  => [-670, 956, -546, -874, 655]
# 98004  => [-665, 958, -545, -877, 652]
# 96874  => [-669, 958, -545, -878, 652]
# 95320  => [-657, 960, -548, -879, 654]
# 90938  => [-657, 957, -552, -881, 657]
# 90697  => [-664, 961, -548, -885, 646]
# 90314  => [-659, 958, -554, -882, 656]
# 87019  => [-658, 956, -555, -884, 657]
# 86153  => [-651, 959, -552, -888, 656]
# 82863  => [-646, 961, -554, -892, 652]
# 79657  => [-643, 958, -559, -894, 657]
# 79016  => [-648, 959, -563, -895, 653]
# 78755  => [-641, 960, -560, -895, 653]
# 77213  => [-645, 962, -561, -900, 649]
# 76852  => [-644, 965, -561, -901, 647]
# 72215  => [-641, 965, -566, -905, 646]
# 69356  => [-639, 966, -571, -910, 644]
# 66861  => [-636, 966, -568, -909, 643]
# 65089  => [-632, 967, -571, -915, 640]
# 63300  => [-627, 967, -572, -918, 641]
# 59565  => [-623, 967, -577, -918, 642]
# 59475  => [-621, 969, -575, -921, 642]
# 57975  => [-624, 969, -575, -919, 640]
# 57607  => [-619, 971, -579, -923, 636]
# 56364  => [-620, 971, -577, -922, 637]
# 54779  => [-620, 971, -576, -924, 636]
# 52189  => [-610, 978, -578, -929, 631]
# 49927  => [-612, 973, -582, -929, 636]
# 48175  => [-605, 974, -581, -935, 631]
# 42959  => [-601, 979, -585, -937, 628]
# 36046  => [-596, 978, -590, -945, 628]
# 31325  => [-592, 983, -591, -951, 620]
# 30399  => [-587, 982, -592, -950, 623]
# 30159  => [-587, 987, -593, -956, 618]
# 29912  => [-587, 991, -592, -960, 613]
# 26373  => [-584, 984, -600, -961, 619]
# 25845  => [-583, 988, -593, -960, 613]
# 24086  => [-583, 986, -594, -958, 616]
# 23849  => [-578, 979, -602, -957, 628]
# 23680  => [-575, 974, -607, -955, 638]
# 23307  => [-575, 976, -603, -955, 633]
# 23208  => [-575, 975, -606, -957, 635]
# 22994  => [-576, 976, -605, -956, 634]
# 22746  => [-572, 972, -607, -954, 640]
# 22674  => [-571, 969, -613, -955, 647]
# 22317  => [-566, 965, -613, -952, 652]
# 22133  => [-565, 962, -616, -952, 657]
# 21701  => [-566, 963, -615, -951, 656]
# 21647  => [-563, 959, -620, -952, 662]
# 21541  => [-563, 959, -619, -950, 662]
# 21364  => [-560, 956, -622, -950, 668]
# 21344  => [-561, 954, -626, -950, 672]
# 21294  => [-561, 956, -621, -948, 668]
# 21239  => [-557, 951, -628, -949, 676]
# 21156  => [-557, 951, -624, -947, 675]
# 20433  => [-557, 952, -624, -947, 675]
# 20270  => [-554, 948, -629, -947, 682]
# 19764  => [-552, 944, -632, -945, 688]
# 19555  => [-550, 941, -635, -944, 694]
# 19471  => [-549, 939, -640, -946, 698]
# 19390  => [-546, 936, -639, -943, 702]
# 18471  => [-544, 934, -641, -942, 705]
# 18269  => [-542, 930, -648, -943, 713]
# 18228  => [-537, 927, -645, -939, 717]
# 18165  => [-541, 929, -645, -940, 714]
# 17732  => [-535, 924, -649, -939, 722]
# 17675  => [-535, 922, -653, -938, 727]
# 17469  => [-538, 925, -652, -941, 722]
# 17451  => [-534, 922, -650, -937, 725]
# 17023  => [-533, 921, -650, -936, 728]
# 16325  => [-531, 918, -654, -936, 733]
# 16210  => [-529, 916, -655, -935, 736]
# 16205  => [-528, 914, -658, -936, 739]
# 16103  => [-528, 914, -656, -934, 739]
# 15767  => [-526, 912, -658, -933, 743]
# 15677  => [-525, 910, -662, -934, 747]
# 15620  => [-524, 907, -669, -936, 753]
# 15359  => [-520, 903, -669, -933, 758]
# 15251  => [-519, 902, -668, -930, 761]
# 14777  => [-517, 899, -674, -932, 766]
# 14591  => [-518, 900, -671, -932, 763]
# 14537  => [-517, 898, -673, -930, 767]
# 14309  => [-516, 897, -672, -929, 768]
# 14306  => [-515, 897, -671, -928, 769]
# 14135  => [-515, 895, -675, -929, 772]
# 14123  => [-513, 895, -672, -927, 772]
# 13674  => [-513, 893, -675, -927, 775]
# 13190  => [-512, 893, -675, -927, 775]
# 13158  => [-511, 891, -678, -927, 779]
# 13110  => [-509, 888, -681, -927, 784]
# 12750  => [-508, 888, -679, -925, 784]
# 12701  => [-508, 887, -682, -926, 786]
# 12593  => [-507, 886, -681, -925, 787]
# 12340  => [-503, 881, -686, -924, 795]
# 12146  => [-502, 878, -691, -924, 802]
# 11935  => [-498, 875, -692, -922, 806]
# 11716  => [-500, 875, -694, -923, 807]
# 11710  => [-499, 875, -693, -922, 807]
# 11132  => [-497, 872, -696, -922, 812]
# 10924  => [-495, 870, -695, -920, 814]
# 9739  => [-490, 864, -701, -918, 825]
# 9679  => [-486, 858, -708, -918, 835]
# 9578  => [-484, 854, -709, -914, 842]
# 9543  => [-483, 854, -709, -914, 841]
# 9408  => [-481, 851, -711, -912, 847]
# 9296  => [-481, 851, -711, -913, 847]
# 8556  => [-480, 851, -712, -914, 847]
# 8018  => [-478, 848, -715, -913, 852]
# 6894  => [-472, 840, -722, -910, 866]
# 6567  => [-468, 834, -729, -909, 877]
# 6537  => [-463, 828, -734, -908, 887]
# 6326  => [-463, 827, -735, -907, 889]
# 6285  => [-459, 823, -736, -904, 896]
# 6127  => [-457, 821, -736, -903, 898]
# 5951  => [-456, 818, -741, -902, 903]
# 5692  => [-458, 821, -738, -903, 899]
# 5422  => [-459, 822, -741, -906, 898]
# 4950  => [-453, 816, -742, -903, 906]
# 4509  => [-455, 818, -740, -902, 903]
# 4215  => [-450, 812, -745, -901, 913]
# 4131  => [-443, 803, -753, -896, 930]
# 3438  => [-443, 801, -755, -896, 933]
# 3227  => [-444, 804, -752, -898, 927]
# 2962  => [-438, 796, -759, -894, 942]
# 2563  => [-442, 801, -755, -897, 932]
# 2467  => [-438, 795, -759, -894, 942]
# 2427  => [-436, 794, -760, -893, 945]
# 2345  => [-437, 793, -762, -894, 946]
# 2182  => [-437, 795, -760, -894, 943]
# 2118  => [-435, 791, -764, -894, 949]
# 1857  => [-434, 791, -765, -894, 950]
# 1617  => [-433, 789, -765, -893, 952]
# 1572  => [-428, 784, -768, -890, 962]
# 1181  => [-426, 781, -772, -890, 966]
# 0  => [-428, 783, -770, -890, 963]
# [-427, 929, -129, -398, 747, 2083074]
# [-607, 318, 287, -775, 823, 1770099]
# [40, -745, -689, 615, -924, -1507087]
# [-744, -644, 401, -186, 195, -141265]
# [-138, -893, 518, -766, -48, -403499]
# [860, 850, 322, -769, 190, 916910]
# [837, 656, -680, -27, 380, 1068982]
# [-733, 641, -214, -427, 461, 1804380]
# [457, -403, -133, -442, 356, 327473]
# [-152, 269, -617, -1000, -516, 1143865]
# [339, -204, 155, -475, 788, 757420]
# [-664, -776, -201, 832, 844, -96354]
# [-695, 842, -240, 878, -529, -149301]
# [-621, 561, -994, -825, 596, 2778629]
# [744, -483, 730, -53, -116, -1323259]
# [-403, -476, -512, -932, -425, 614221]
# [719, 246, -728, 90, -394, -14076]
# [-734, 590, 958, -746, -440, 278682]
# [277, -351, -750, 162, 210, 242161]
# [680, 909, -197, -380, 124, 1030009]
# [53, -526, -787, -717, -712, 123922]
# [-46, -396, 293, -376, -970, -1115460]
# [-667, 556, -287, 429, -527, 52503]
# [109, -330, -490, 122, 938, 866972]
# [-265, -699, 118, -247, -671, -951100]
# [78, -455, 472, -594, 668, 418855]
# [-909, -744, -246, -111, -91, 7077]
# [709, 697, 808, 307, 507, -164850]
# [610, 746, -851, 351, -347, 331757]
# [634, 417, -526, 294, -348, -136605]
# [111, -79, 801, -610, 601, 395528]
# [99, -1, 635, -328, 10, -230555]
# [-576, 392, -830, 227, -162, 834528]
# [-505, 304, -957, 19, -410, 779322]
# [978, -988, 95, 594, -189, -1976005]
# [-684, 419, 818, -940, -645, 206434]
# [865, 943, -558, -693, -286, 1139161]
# [866, -2, 544, 586, 942, -405488]
# [67, 808, -550, 458, -712, -65788]
# [-514, -603, -875, 535, -949, -968444]
# [-155, 201, 686, -217, 327, 203534]
# [225, -230, -900, -927, 486, 1709658]
# [-876, 40, -427, 237, -822, -267478]
# [-23, -764, 493, 683, -74, -1647110]
# [-968, 510, -620, -53, -301, 1048341]
# [878, -19, 216, -932, -272, 10563]
# [100, 559, 251, 268, -400, -422093]
# ------------------ 47 ----------------> [-428, 783, -770, -890, 963]
# dit 0
# Gene C==> 11
# 848090  => [-858, 984, -777, -652, 598]
# 840382  => [-859, 985, -776, -655, 601]
# 827557  => [-857, 988, -771, -659, 601]
# 813105  => [-852, 991, -770, -664, 606]
# 799163  => [-848, 991, -765, -668, 606]
# 791154  => [-844, 994, -762, -670, 606]
# 776710  => [-844, 1000, -756, -674, 608]
# 772168  => [-839, 996, -753, -674, 606]
# 761826  => [-846, 998, -751, -678, 612]
# 700708  => [-846, 612, -839, -677, 998]
# 693613  => [-848, 614, -842, -676, 999]
# 678176  => [-850, 620, -840, -675, 1000]
# 667205  => [-840, 621, -840, -678, 1000]
# 662686  => [-841, 625, -842, -681, 995]
# 657110  => [-838, 630, -847, -677, 1000]
# 651922  => [-836, 631, -842, -680, 997]
# 642488  => [-833, 635, -837, -681, 997]
# 636035  => [-837, 639, -832, -684, 998]
# 629479  => [-833, 643, -830, -682, 998]
# 620724  => [-830, 646, -826, -684, 998]
# 612776  => [-827, 651, -824, -684, 997]
# 605731  => [-824, 652, -825, -689, 997]
# 598061  => [-819, 651, -822, -693, 998]
# 591970  => [-815, 654, -820, -692, 1000]
# 587878  => [-815, 655, -814, -695, 999]
# 580447  => [-810, 657, -814, -697, 998]
# 580099  => [-810, 655, -815, -698, 998]
# 573904  => [-805, 658, -813, -696, 998]
# 572451  => [-806, 657, -813, -703, 994]
# 567458  => [-805, 661, -812, -706, 989]
# 563577  => [-798, 665, -803, -688, 998]
# 561041  => [-799, 665, -816, -707, 988]
# 452145  => [-799, 988, -707, -803, 665]
# 447541  => [-794, 985, -707, -804, 666]
# 438195  => [-790, 985, -707, -808, 668]
# 427785  => [-787, 984, -706, -812, 673]
# 417998  => [-782, 979, -707, -817, 671]
# 414525  => [-783, 975, -702, -820, 676]
# 406394  => [-778, 973, -700, -820, 679]
# 398469  => [-775, 974, -697, -827, 677]
# 393049  => [-776, 970, -699, -826, 671]
# 388400  => [-773, 973, -694, -825, 667]
# 385085  => [-771, 960, -693, -822, 673]
# 381261  => [-772, 975, -689, -827, 664]
# 372953  => [-772, 965, -683, -824, 670]
# 367217  => [-771, 963, -681, -827, 670]
# 358200  => [-772, 958, -676, -830, 666]
# 354287  => [-769, 955, -680, -834, 666]
# 346304  => [-763, 959, -669, -827, 673]
# 337516  => [-761, 959, -666, -831, 669]
# 327309  => [-757, 956, -661, -834, 665]
# 321395  => [-753, 960, -657, -833, 667]
# 316999  => [-756, 952, -655, -837, 669]
# 309450  => [-751, 959, -652, -840, 659]
# 300056  => [-747, 951, -654, -845, 661]
# 295603  => [-743, 948, -657, -848, 663]
# 286853  => [-742, 953, -652, -852, 662]
# 280010  => [-737, 954, -649, -855, 654]
# 274201  => [-739, 957, -646, -859, 650]
# 261508  => [-734, 952, -644, -862, 654]
# 255295  => [-729, 956, -642, -866, 655]
# 251253  => [-729, 952, -643, -867, 653]
# 249008  => [-723, 961, -636, -871, 659]
# 243135  => [-718, 958, -637, -863, 663]
# 233115  => [-714, 959, -634, -865, 660]
# 224893  => [-712, 957, -636, -875, 652]
# 222777  => [-713, 964, -625, -872, 653]
# 218075  => [-708, 968, -620, -873, 657]
# 207877  => [-707, 965, -617, -871, 652]
# 207077  => [-709, 962, -613, -873, 653]
# 196100  => [-701, 958, -608, -870, 662]
# 187567  => [-697, 962, -607, -872, 657]
# 181494  => [-695, 959, -605, -874, 653]
# 176377  => [-692, 961, -601, -875, 650]
# 168949  => [-694, 956, -598, -878, 649]
# 161356  => [-684, 959, -601, -881, 653]
# 151824  => [-682, 961, -596, -886, 653]
# 140031  => [-677, 957, -593, -886, 654]
# 131468  => [-672, 955, -591, -889, 653]
# 129965  => [-675, 959, -589, -894, 648]
# 119735  => [-668, 957, -587, -893, 652]
# 112085  => [-666, 964, -585, -903, 643]
# 105497  => [-662, 964, -582, -904, 645]
# 100848  => [-663, 966, -577, -907, 640]
# 93181  => [-658, 962, -578, -906, 643]
# 87829  => [-656, 967, -573, -906, 640]
# 84788  => [-654, 968, -575, -911, 638]
# 75722  => [-648, 972, -569, -911, 638]
# 70721  => [-643, 972, -566, -911, 635]
# 69343  => [-642, 969, -566, -910, 638]
# 69262  => [-638, 973, -566, -912, 635]
# 67654  => [-634, 971, -569, -913, 635]
# 65191  => [-633, 973, -571, -918, 636]
# 59748  => [-628, 972, -569, -918, 634]
# 54325  => [-616, 975, -574, -924, 632]
# 53949  => [-616, 975, -575, -924, 632]
# 53509  => [-616, 979, -573, -932, 626]
# 50511  => [-615, 979, -573, -930, 624]
# 50031  => [-614, 979, -575, -934, 624]
# 49510  => [-611, 984, -572, -934, 620]
# 48381  => [-616, 982, -573, -934, 619]
# 46156  => [-607, 983, -575, -936, 621]
# 43257  => [-608, 984, -581, -943, 619]
# 43202  => [-605, 983, -581, -943, 621]
# 42843  => [-604, 989, -577, -946, 614]
# 41091  => [-600, 985, -579, -942, 618]
# 38268  => [-601, 985, -583, -947, 617]
# 37243  => [-599, 993, -584, -952, 608]
# 30157  => [-595, 994, -583, -957, 603]
# 28552  => [-593, 995, -587, -962, 599]
# 27544  => [-597, 1000, -586, -965, 594]
# 27402  => [-593, 996, -585, -961, 598]
# 26837  => [-591, 995, -585, -961, 600]
# 26250  => [-589, 991, -592, -961, 609]
# 25206  => [-585, 988, -594, -961, 612]
# 24926  => [-580, 983, -596, -958, 621]
# 24552  => [-578, 980, -601, -958, 626]
# 24374  => [-582, 984, -599, -960, 620]
# 24118  => [-580, 980, -606, -961, 628]
# 24011  => [-579, 977, -611, -961, 634]
# 23724  => [-578, 977, -608, -959, 633]
# 23706  => [-576, 974, -611, -959, 638]
# 22732  => [-573, 973, -606, -954, 639]
# 22638  => [-572, 970, -610, -954, 644]
# 22136  => [-568, 967, -611, -952, 649]
# 22099  => [-565, 963, -616, -952, 656]
# 22015  => [-562, 960, -617, -950, 661]
# 21910  => [-563, 960, -618, -952, 660]
# 21835  => [-565, 963, -615, -951, 656]
# 21813  => [-564, 961, -618, -951, 660]
# 21423  => [-563, 958, -621, -950, 665]
# 21253  => [-559, 953, -623, -947, 672]
# 21152  => [-559, 954, -625, -949, 672]
# 20603  => [-557, 952, -625, -948, 675]
# 20478  => [-553, 946, -632, -949, 684]
# 20350  => [-553, 946, -631, -948, 684]
# 19942  => [-549, 940, -635, -944, 694]
# 19791  => [-550, 940, -635, -943, 695]
# 19687  => [-547, 938, -636, -941, 699]
# 18449  => [-546, 937, -638, -943, 700]
# 18433  => [-545, 935, -642, -944, 704]
# 17918  => [-543, 933, -641, -941, 707]
# 17878  => [-540, 930, -642, -939, 712]
# 17576  => [-537, 926, -646, -939, 718]
# 17066  => [-538, 927, -646, -939, 717]
# 16928  => [-537, 925, -649, -939, 721]
# 16871  => [-534, 922, -650, -938, 725]
# 16739  => [-535, 923, -650, -938, 724]
# 16412  => [-532, 919, -654, -937, 731]
# 16205  => [-528, 914, -658, -936, 739]
# 16174  => [-527, 913, -659, -935, 741]
# 15970  => [-528, 913, -657, -933, 741]
# 15724  => [-526, 911, -660, -933, 745]
# 15597  => [-525, 909, -664, -935, 748]
# 15384  => [-524, 908, -664, -934, 750]
# 15110  => [-523, 907, -664, -933, 751]
# 14894  => [-520, 904, -665, -931, 756]
# 14607  => [-519, 902, -667, -931, 759]
# 14277  => [-519, 901, -670, -931, 762]
# 14116  => [-515, 897, -672, -929, 769]
# 14098  => [-515, 896, -674, -930, 770]
# 14040  => [-516, 897, -675, -931, 769]
# 13226  => [-511, 891, -679, -928, 779]
# 13198  => [-505, 883, -683, -923, 793]
# 13108  => [-509, 888, -682, -928, 784]
# 12903  => [-505, 884, -685, -926, 791]
# 12838  => [-505, 882, -686, -925, 794]
# 12340  => [-503, 881, -686, -924, 795]
# 12245  => [-502, 879, -691, -925, 800]
# 12173  => [-503, 879, -690, -924, 800]
# 11826  => [-500, 876, -690, -922, 804]
# 11694  => [-497, 874, -693, -922, 808]
# 11481  => [-493, 868, -697, -921, 817]
# 10864  => [-495, 871, -694, -920, 813]
# 10836  => [-494, 868, -698, -920, 818]
# 10427  => [-491, 866, -698, -918, 821]
# 9739  => [-490, 864, -701, -918, 825]
# 9562  => [-487, 860, -704, -916, 832]
# 9431  => [-485, 855, -714, -918, 842]
# 9290  => [-481, 851, -714, -916, 847]
# 8954  => [-479, 850, -713, -914, 848]
# 8869  => [-478, 849, -714, -914, 850]
# 8813  => [-478, 848, -716, -914, 853]
# 8051  => [-476, 846, -716, -912, 855]
# 7771  => [-475, 844, -717, -910, 859]
# 7761  => [-474, 843, -718, -911, 860]
# 7713  => [-473, 840, -724, -911, 867]
# 6932  => [-469, 836, -724, -908, 872]
# 6892  => [-471, 838, -726, -911, 870]
# 6672  => [-468, 834, -726, -907, 876]
# 6567  => [-468, 834, -729, -909, 877]
# 6466  => [-466, 833, -727, -908, 877]
# 6382  => [-466, 832, -729, -907, 880]
# 6313  => [-466, 833, -727, -907, 878]
# 6286  => [-467, 834, -726, -907, 876]
# 6167  => [-464, 830, -731, -907, 883]
# 6126  => [-460, 824, -735, -905, 892]
# 6046  => [-463, 826, -740, -909, 892]
# 5670  => [-461, 826, -734, -905, 890]
# 5172  => [-457, 820, -738, -902, 900]
# 5039  => [-457, 821, -738, -904, 898]
# 4715  => [-454, 816, -742, -901, 907]
# 4523  => [-452, 813, -745, -901, 912]
# 4267  => [-448, 808, -749, -899, 921]
# 4215  => [-450, 812, -745, -901, 913]
# 3860  => [-446, 805, -752, -899, 925]
# 3497  => [-446, 807, -750, -899, 922]
# 3468  => [-445, 804, -756, -900, 928]
# 3438  => [-443, 801, -755, -896, 933]
# 3218  => [-444, 803, -752, -896, 929]
# 3192  => [-441, 799, -758, -896, 937]
# 2744  => [-436, 793, -762, -894, 945]
# 2118  => [-435, 791, -765, -894, 949]
# 1950  => [-437, 794, -761, -894, 944]
# 1576  => [-434, 791, -763, -893, 949]
# 1250  => [-430, 785, -769, -891, 959]
# 1195  => [-431, 787, -766, -891, 956]
# 1181  => [-430, 785, -768, -890, 960]
# 973  => [-429, 784, -770, -891, 961]
# 903  => [-431, 787, -767, -892, 956]
# 0  => [-428, 783, -770, -890, 963]
# [-427, 929, -129, -398, 747, 2083074]
# [-607, 318, 287, -775, 823, 1770099]
# [40, -745, -689, 615, -924, -1507087]
# [-744, -644, 401, -186, 195, -141265]
# [-138, -893, 518, -766, -48, -403499]
# [860, 850, 322, -769, 190, 916910]
# [837, 656, -680, -27, 380, 1068982]
# [-733, 641, -214, -427, 461, 1804380]
# [457, -403, -133, -442, 356, 327473]
# [-152, 269, -617, -1000, -516, 1143865]
# [339, -204, 155, -475, 788, 757420]
# [-664, -776, -201, 832, 844, -96354]
# [-695, 842, -240, 878, -529, -149301]
# [-621, 561, -994, -825, 596, 2778629]
# [744, -483, 730, -53, -116, -1323259]
# [-403, -476, -512, -932, -425, 614221]
# [719, 246, -728, 90, -394, -14076]
# [-734, 590, 958, -746, -440, 278682]
# [277, -351, -750, 162, 210, 242161]
# [680, 909, -197, -380, 124, 1030009]
# [53, -526, -787, -717, -712, 123922]
# [-46, -396, 293, -376, -970, -1115460]
# [-667, 556, -287, 429, -527, 52503]
# [109, -330, -490, 122, 938, 866972]
# [-265, -699, 118, -247, -671, -951100]
# [78, -455, 472, -594, 668, 418855]
# [-909, -744, -246, -111, -91, 7077]
# [709, 697, 808, 307, 507, -164850]
# [610, 746, -851, 351, -347, 331757]
# [634, 417, -526, 294, -348, -136605]
# [111, -79, 801, -610, 601, 395528]
# [99, -1, 635, -328, 10, -230555]
# [-576, 392, -830, 227, -162, 834528]
# [-505, 304, -957, 19, -410, 779322]
# [978, -988, 95, 594, -189, -1976005]
# [-684, 419, 818, -940, -645, 206434]
# [865, 943, -558, -693, -286, 1139161]
# [866, -2, 544, 586, 942, -405488]
# [67, 808, -550, 458, -712, -65788]
# [-514, -603, -875, 535, -949, -968444]
# [-155, 201, 686, -217, 327, 203534]
# [225, -230, -900, -927, 486, 1709658]
# [-876, 40, -427, 237, -822, -267478]
# [-23, -764, 493, 683, -74, -1647110]
# [-968, 510, -620, -53, -301, 1048341]
# [878, -19, 216, -932, -272, 10563]
# [100, 559, 251, 268, -400, -422093]
# ------------------ 47 ----------------> [-428, 783, -770, -890, 963]
# 852017  => [-859, 991, -778, -652, 596]
# 835117  => [-845, 987, -766, -652, 596]
# 825715  => [-840, 985, -762, -653, 600]
# 809574  => [-841, 986, -757, -655, 602]
# 804334  => [-838, 991, -755, -654, 607]
# 802500  => [-844, 982, -759, -663, 600]
# 791640  => [-838, 995, -748, -655, 611]
# 782096  => [-835, 995, -750, -659, 617]
# 769521  => [-830, 991, -745, -664, 612]
# 756102  => [-831, 995, -744, -667, 623]
# 751367  => [-829, 999, -741, -667, 624]
# 744976  => [-832, 985, -742, -673, 621]
# 738042  => [-826, 998, -740, -671, 630]
# 727375  => [-830, 990, -734, -674, 629]
# 721027  => [-825, 987, -730, -673, 630]
# 710228  => [-824, 983, -725, -674, 633]
# 697128  => [-819, 979, -720, -675, 637]
# 689750  => [-816, 974, -716, -675, 638]
# 680836  => [-816, 978, -716, -680, 640]
# 665540  => [-818, 979, -711, -684, 645]
# 649451  => [-814, 974, -706, -689, 645]
# 634084  => [-811, 977, -703, -694, 649]
# 622426  => [-812, 974, -698, -699, 646]
# 613567  => [-807, 975, -696, -700, 650]
# 596022  => [-803, 970, -691, -704, 654]
# 591221  => [-807, 970, -689, -706, 655]
# 580344  => [-793, 969, -691, -710, 657]
# 566021  => [-788, 965, -687, -714, 658]
# 556071  => [-793, 967, -686, -719, 662]
# 554490  => [-791, 965, -681, -715, 663]
# 546011  => [-792, 977, -680, -727, 650]
# 535861  => [-802, 960, -682, -729, 665]
# 523447  => [-791, 978, -670, -731, 655]
# 518403  => [-796, 969, -671, -737, 652]
# 505709  => [-796, 972, -666, -739, 657]
# 490442  => [-791, 977, -661, -743, 659]
# 480987  => [-795, 975, -658, -748, 658]
# 469044  => [-790, 975, -657, -756, 653]
# 457270  => [-791, 972, -649, -752, 664]
# 449365  => [-790, 977, -650, -756, 668]
# 437883  => [-785, 982, -645, -760, 665]
# 427056  => [-790, 987, -643, -765, 669]
# 419064  => [-789, 973, -642, -769, 667]
# 407064  => [-791, 991, -635, -773, 667]
# 396661  => [-793, 990, -631, -775, 671]
# 390933  => [-796, 985, -626, -779, 672]
# 381724  => [-793, 974, -626, -778, 674]
# 371105  => [-787, 972, -626, -784, 677]
# 365953  => [-782, 973, -628, -788, 678]
# 362920  => [-783, 973, -625, -789, 675]
# 360025  => [-782, 968, -618, -781, 677]
# 355799  => [-780, 977, -621, -792, 672]
# 350365  => [-782, 965, -619, -793, 666]
# 344470  => [-780, 965, -618, -795, 667]
# 336774  => [-778, 964, -613, -794, 670]
# 330359  => [-770, 971, -611, -797, 666]
# 326501  => [-777, 961, -604, -795, 666]
# 320597  => [-770, 961, -604, -798, 664]
# 310784  => [-769, 960, -599, -801, 662]
# 295527  => [-764, 958, -594, -804, 665]
# 290655  => [-761, 951, -591, -804, 664]
# 285163  => [-759, 954, -590, -805, 667]
# 278661  => [-758, 956, -590, -810, 665]
# 267848  => [-760, 944, -579, -810, 668]
# 264198  => [-761, 946, -574, -808, 664]
# 257857  => [-756, 944, -575, -815, 667]
# 250368  => [-757, 937, -573, -817, 657]
# 241952  => [-753, 939, -571, -819, 659]
# 235986  => [-749, 939, -566, -816, 663]
# 229269  => [-747, 943, -568, -825, 656]
# 222971  => [-745, 940, -567, -828, 655]
# 216392  => [-742, 937, -564, -833, 655]
# 212522  => [-739, 942, -565, -832, 656]
# 206140  => [-739, 937, -557, -837, 659]
# 205904  => [-740, 938, -559, -841, 654]
# 202229  => [-733, 940, -566, -839, 655]
# 198344  => [-731, 941, -563, -842, 657]
# 195940  => [-727, 946, -562, -842, 658]
# 188393  => [-723, 942, -566, -843, 657]
# 184438  => [-726, 941, -545, -843, 655]
# 172918  => [-722, 942, -540, -846, 660]
# 168029  => [-717, 943, -539, -846, 664]
# 162639  => [-712, 945, -536, -842, 662]
# 156966  => [-708, 950, -536, -840, 660]
# 155899  => [-710, 954, -529, -848, 661]
# 147776  => [-705, 946, -534, -850, 664]
# 147272  => [-705, 958, -533, -848, 654]
# 146084  => [-702, 946, -539, -855, 664]
# 144283  => [-699, 958, -542, -853, 655]
# 133836  => [-692, 947, -538, -855, 665]
# 130424  => [-692, 957, -523, -845, 657]
# 126269  => [-688, 954, -540, -858, 657]
# 124671  => [-688, 952, -546, -867, 655]
# 121557  => [-684, 950, -542, -865, 659]
# 118335  => [-683, 957, -546, -866, 652]
# 108853  => [-675, 953, -543, -868, 660]
# 107292  => [-670, 954, -543, -864, 664]
# 103494  => [-667, 951, -544, -869, 663]
# 101075  => [-665, 953, -548, -873, 660]
# 99606  => [-667, 954, -548, -878, 656]
# 97800  => [-661, 956, -549, -874, 662]
# 96092  => [-651, 955, -548, -879, 661]
# 95339  => [-668, 960, -547, -883, 649]
# 93457  => [-661, 958, -549, -879, 655]
# 93398  => [-658, 959, -551, -880, 657]
# 87953  => [-654, 957, -552, -885, 656]
# 86760  => [-657, 957, -557, -888, 653]
# 85428  => [-655, 961, -557, -893, 651]
# 83698  => [-652, 958, -561, -897, 650]
# 79192  => [-649, 962, -558, -897, 648]
# 78770  => [-646, 960, -559, -894, 652]
# 77532  => [-639, 968, -559, -904, 646]
# 71035  => [-635, 966, -563, -907, 645]
# 70153  => [-634, 968, -566, -906, 643]
# 69309  => [-627, 968, -570, -908, 643]
# 68879  => [-632, 968, -566, -907, 643]
# 62332  => [-626, 965, -574, -913, 647]
# 61731  => [-624, 972, -567, -918, 635]
# 58474  => [-621, 969, -578, -924, 641]
# 56947  => [-625, 973, -575, -923, 634]
# 56879  => [-619, 968, -583, -923, 645]
# 55216  => [-617, 971, -584, -926, 641]
# 50846  => [-613, 970, -588, -930, 642]
# 50214  => [-612, 970, -583, -929, 638]
# 48923  => [-608, 974, -585, -933, 637]
# 48224  => [-605, 973, -585, -938, 635]
# 48065  => [-609, 973, -588, -934, 638]
# 46492  => [-607, 970, -592, -936, 642]
# 41952  => [-604, 980, -585, -941, 626]
# 39596  => [-596, 980, -588, -942, 628]
# 37331  => [-598, 978, -588, -943, 627]
# 33822  => [-594, 982, -588, -948, 622]
# 32162  => [-594, 983, -594, -953, 621]
# 31880  => [-593, 988, -594, -957, 616]
# 29447  => [-585, 983, -602, -958, 626]
# 29089  => [-586, 980, -607, -960, 631]
# 25419  => [-580, 980, -603, -958, 629]
# 24739  => [-581, 981, -602, -959, 626]
# 23958  => [-577, 977, -603, -956, 631]
# 23260  => [-569, 968, -610, -953, 646]
# 22408  => [-571, 970, -609, -953, 644]
# 22269  => [-565, 962, -618, -952, 659]
# 21405  => [-563, 959, -617, -949, 662]
# 21117  => [-560, 956, -621, -949, 667]
# 20701  => [-559, 954, -624, -949, 671]
# 20653  => [-556, 950, -627, -947, 679]
# 20500  => [-554, 947, -632, -949, 683]
# 20368  => [-552, 946, -630, -947, 684]
# 20273  => [-552, 943, -634, -945, 690]
# 19910  => [-552, 944, -633, -946, 688]
# 19696  => [-553, 947, -629, -946, 683]
# 19605  => [-553, 946, -631, -946, 685]
# 19526  => [-550, 943, -632, -945, 689]
# 18908  => [-549, 941, -633, -943, 693]
# 18860  => [-545, 936, -639, -942, 702]
# 18689  => [-547, 939, -635, -943, 696]
# 18435  => [-545, 935, -641, -943, 704]
# 18296  => [-544, 935, -639, -942, 703]
# 18204  => [-539, 929, -644, -940, 713]
# 17553  => [-540, 929, -646, -941, 714]
# 17372  => [-536, 924, -648, -937, 722]
# 17014  => [-534, 921, -652, -938, 727]
# 16932  => [-533, 918, -660, -940, 734]
# 16557  => [-533, 919, -656, -938, 732]
# 15905  => [-526, 910, -662, -934, 747]
# 15758  => [-526, 911, -662, -935, 745]
# 15444  => [-525, 910, -661, -934, 746]
# 15236  => [-521, 904, -668, -934, 756]
# 15108  => [-521, 904, -667, -932, 756]
# 14872  => [-518, 901, -669, -931, 761]
# 14775  => [-517, 899, -671, -931, 764]
# 14766  => [-522, 905, -666, -932, 755]
# 14755  => [-518, 901, -668, -929, 762]
# 14624  => [-518, 899, -671, -930, 765]
# 14529  => [-520, 903, -666, -930, 758]
# 14189  => [-513, 894, -673, -927, 773]
# 14163  => [-516, 897, -671, -928, 768]
# 13655  => [-513, 893, -677, -928, 776]
# 13603  => [-512, 892, -678, -929, 777]
# 13228  => [-510, 891, -676, -926, 779]
# 13152  => [-505, 885, -682, -925, 789]
# 13110  => [-509, 888, -681, -927, 784]
# 12378  => [-505, 884, -683, -925, 790]
# 12340  => [-503, 881, -686, -924, 795]
# 11597  => [-499, 875, -693, -923, 806]
# 11495  => [-496, 871, -698, -922, 814]
# 10836  => [-494, 868, -698, -920, 818]
# 10802  => [-494, 867, -702, -921, 821]
# 10427  => [-491, 866, -698, -918, 821]
# 10425  => [-493, 867, -700, -920, 820]
# 10267  => [-489, 863, -701, -917, 826]
# 10172  => [-491, 865, -700, -918, 823]
# 9848  => [-488, 860, -705, -917, 832]
# 9566  => [-485, 857, -707, -916, 837]
# 9560  => [-487, 857, -714, -920, 839]
# 9475  => [-482, 853, -713, -916, 844]
# 9398  => [-485, 856, -712, -918, 840]
# 9320  => [-481, 852, -711, -915, 844]
# 9192  => [-484, 856, -708, -916, 838]
# 8827  => [-479, 849, -715, -914, 850]
# 8730  => [-480, 849, -716, -914, 851]
# 8685  => [-478, 848, -714, -913, 851]
# 8565  => [-477, 846, -717, -912, 855]
# 8468  => [-477, 845, -722, -914, 859]
# 7647  => [-472, 841, -719, -909, 864]
# 7574  => [-473, 840, -722, -910, 866]
# 7465  => [-469, 835, -725, -907, 874]
# 7227  => [-466, 832, -730, -910, 879]
# 6286  => [-467, 834, -726, -907, 876]
# 5805  => [-461, 827, -732, -905, 888]
# 5746  => [-457, 820, -740, -905, 900]
# 5616  => [-457, 819, -745, -907, 903]
# 5318  => [-456, 819, -741, -905, 901]
# 5275  => [-454, 816, -745, -905, 907]
# 5227  => [-451, 814, -743, -901, 911]
# 4435  => [-449, 811, -746, -900, 916]
# 4326  => [-447, 807, -751, -901, 921]
# 4122  => [-445, 806, -749, -897, 924]
# 3523  => [-444, 804, -753, -899, 927]
# 3195  => [-442, 802, -754, -897, 931]
# 2939  => [-441, 800, -756, -896, 935]
# 2563  => [-442, 801, -755, -897, 932]
# 2519  => [-441, 799, -758, -897, 936]
# 2239  => [-438, 796, -759, -895, 941]
# 1507  => [-436, 793, -762, -894, 946]
# 1461  => [-434, 790, -765, -893, 951]
# 903  => [-431, 787, -767, -892, 956]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-80f249ae8bf0> in <module>
#     385 while time.time() - start < tm or nb_resolut >= len(list_my_data)  :
#     386     population = new_generation(best[2])
# --> 387     best = get_best(population)
#     388     distance = best[1]
#     389     if mindis > distance :
#
# <ipython-input-16-80f249ae8bf0> in get_best(list_Gene)
#     117             liste_2.insert(0, [dist, x])
#     118         else:
# --> 119             liste_2.append([dist, x])
#     120     liste_2.sort()
#     121     liste_3 = liste_2
#
# KeyboardInterrupt:
